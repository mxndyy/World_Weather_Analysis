# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import timeit
import json

# Import the requests library.
import requests

# Import the time library and the datetime module from the datetime library 
from datetime import datetime

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the API key.
from config import weather_api_key

# %%
# url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)
cities = []

# %%
#Get the nearest city using the citipy module.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 744

# %%
print(city)
# Out:
# tuktoyaktuk

# %%
#Perform an API call with the OpenWeatherMap.
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Retrieve the following information from the API call:
    #Latitude and longitude
    #Maximum temperature
    #Percent humidity
    #Percent cloudiness
    #Wind speed
    #Weather description (for example, clouds, fog, light rain, clear sky)
    #Add the data to a new DataFrame.
    
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | vallenar
# Processing Record 4 of Set 1 | castro
# Processing Record 5 of Set 1 | bilibino
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | new norfolk
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | booue
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | kahului
# Processing Record 12 of Set 1 | sinnamary
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 1 | airai
# Processing Record 17 of Set 1 | yining
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | namatanai
# Processing Record 20 of Set 1 | ahwa
# Processing Record 21 of Set 1 | muros
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | laguna
# Processing Record 24 of Set 1 | barrow
# Processing Record 25 of Set 1 | san quintin
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | tasiilaq
# Processing Record 28 of Set 1 | iqaluit
# Processing Record 29 of Set 1 | dikson
# Processing Record 30 of Set 1 | arraial do cabo
# Processing Record 31 of Set 1 | iberia
# Processing Record 32 of Set 1 | kruisfontein
# Processing Record 33 of Set 1 | faanui
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | victoria
# Processing Record 36 of Set 1 | puerto carreno
# Processing Record 37 of Set 1 | port alfred
# Processing Record 38 of Set 1 | esperance
# Processing Record 39 of Set 1 | saint-philippe
# Processing Record 40 of Set 1 | east london
# Processing Record 41 of Set 1 | saint-michel-des-saints
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | isangel
# Processing Record 44 of Set 1 | namibe
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | geraldton
# Processing Record 47 of Set 1 | kongolo
# Processing Record 48 of Set 1 | carnarvon
# Processing Record 49 of Set 1 | ouesso
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | tezu
# Processing Record 2 of Set 2 | ancud
# Processing Record 3 of Set 2 | stonewall
# Processing Record 4 of Set 2 | hendek
# Processing Record 5 of Set 2 | moron
# Processing Record 6 of Set 2 | huarmey
# Processing Record 7 of Set 2 | butaritari
# Processing Record 8 of Set 2 | peterhead
# Processing Record 9 of Set 2 | lorengau
# Processing Record 10 of Set 2 | katobu
# Processing Record 11 of Set 2 | salalah
# Processing Record 12 of Set 2 | anlu
# Processing Record 13 of Set 2 | fairbanks
# Processing Record 14 of Set 2 | albany
# Processing Record 15 of Set 2 | vaini
# Processing Record 16 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 17 of Set 2 | quatre cocos
# Processing Record 18 of Set 2 | saskylakh
# Processing Record 19 of Set 2 | carndonagh
# Processing Record 20 of Set 2 | luganville
# Processing Record 21 of Set 2 | mahebourg
# Processing Record 22 of Set 2 | genhe
# Processing Record 23 of Set 2 | roald
# Processing Record 24 of Set 2 | keflavik
# Processing Record 25 of Set 2 | bambous virieux
# Processing Record 26 of Set 2 | kapaa
# Processing Record 27 of Set 2 | vila velha
# Processing Record 28 of Set 2 | makakilo city
# Processing Record 29 of Set 2 | abu dhabi
# Processing Record 30 of Set 2 | coquimbo
# Processing Record 31 of Set 2 | tigil
# Processing Record 32 of Set 2 | qaanaaq
# Processing Record 33 of Set 2 | narsaq
# Processing Record 34 of Set 2 | grindavik
# Processing Record 35 of Set 2 | salta
# Processing Record 36 of Set 2 | emporia
# Processing Record 37 of Set 2 | castlemaine
# Processing Record 38 of Set 2 | trincomalee
# Processing Record 39 of Set 2 | kailua
# Processing Record 40 of Set 2 | ayan
# Processing Record 41 of Set 2 | vardo
# Processing Record 42 of Set 2 | nome
# Processing Record 43 of Set 2 | kavieng
# Processing Record 44 of Set 2 | bredasdorp
# Processing Record 45 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 2 | hobart
# Processing Record 47 of Set 2 | georgetown
# Processing Record 48 of Set 2 | taoudenni
# Processing Record 49 of Set 2 | taseyevo
# Processing Record 50 of Set 2 | vitre
# Processing Record 1 of Set 3 | cape town
# Processing Record 2 of Set 3 | pec
# Processing Record 3 of Set 3 | lebu
# Processing Record 4 of Set 3 | qui nhon
# Processing Record 5 of Set 3 | birjand
# Processing Record 6 of Set 3 | upernavik
# Processing Record 7 of Set 3 | scarborough
# Processing Record 8 of Set 3 | chokurdakh
# Processing Record 9 of Set 3 | eenhana
# Processing Record 10 of Set 3 | saint-augustin
# Processing Record 11 of Set 3 | hasaki
# Processing Record 12 of Set 3 | pathein
# Processing Record 13 of Set 3 | rocha
# Processing Record 14 of Set 3 | vilyuysk
# Processing Record 15 of Set 3 | port lincoln
# Processing Record 16 of Set 3 | roma
# Processing Record 17 of Set 3 | neuquen
# Processing Record 18 of Set 3 | tiarei
# Processing Record 19 of Set 3 | ribeira grande
# Processing Record 20 of Set 3 | akdepe
# Processing Record 21 of Set 3 | severo-kurilsk
# Processing Record 22 of Set 3 | jamestown
# Processing Record 23 of Set 3 | soe
# Processing Record 24 of Set 3 | anloga
# Processing Record 25 of Set 3 | rize
# Processing Record 26 of Set 3 | mogok
# Processing Record 27 of Set 3 | lishui
# Processing Record 28 of Set 3 | sao filipe
# Processing Record 29 of Set 3 | inirida
# Processing Record 30 of Set 3 | davila
# Processing Record 31 of Set 3 | vostok
# Processing Record 32 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 3 | okhotsk
# Processing Record 35 of Set 3 | trofors
# Processing Record 36 of Set 3 | pundaguitan
# Processing Record 37 of Set 3 | thompson
# Processing Record 38 of Set 3 | damghan
# Processing Record 39 of Set 3 | eregli
# Processing Record 40 of Set 3 | glens falls
# Processing Record 41 of Set 3 | vuktyl
# Processing Record 42 of Set 3 | dunedin
# Processing Record 43 of Set 3 | mar del plata
# Processing Record 44 of Set 3 | longyearbyen
# Processing Record 45 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 3 | neuhof
# Processing Record 47 of Set 3 | pevek
# Processing Record 48 of Set 3 | yangambi
# Processing Record 49 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 50 of Set 3 | ola
# Processing Record 1 of Set 4 | asau
# Processing Record 2 of Set 4 | karoi
# Processing Record 3 of Set 4 | acajutla
# Processing Record 4 of Set 4 | porto novo
# Processing Record 5 of Set 4 | moose factory
# Processing Record 6 of Set 4 | sassandra
# Processing Record 7 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 4 | arona
# Processing Record 9 of Set 4 | bhitarwar
# Processing Record 10 of Set 4 | seoul
# Processing Record 11 of Set 4 | ukiah
# Processing Record 12 of Set 4 | viedma
# Processing Record 13 of Set 4 | sitka
# Processing Record 14 of Set 4 | jiroft
# City not found. Skipping...
# Processing Record 15 of Set 4 | foam lake
# Processing Record 16 of Set 4 | afmadu
# City not found. Skipping...
# Processing Record 17 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 18 of Set 4 | buraydah
# Processing Record 19 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 20 of Set 4 | ust-ishim
# Processing Record 21 of Set 4 | ponta do sol
# Processing Record 22 of Set 4 | pangnirtung
# Processing Record 23 of Set 4 | sarakhs
# Processing Record 24 of Set 4 | tuatapere
# Processing Record 25 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 4 | lensk
# Processing Record 28 of Set 4 | klaksvik
# Processing Record 29 of Set 4 | sistranda
# Processing Record 30 of Set 4 | linxia
# Processing Record 31 of Set 4 | bathsheba
# Processing Record 32 of Set 4 | puerto ayora
# Processing Record 33 of Set 4 | tiksi
# Processing Record 34 of Set 4 | jalpan
# Processing Record 35 of Set 4 | bethel
# Processing Record 36 of Set 4 | chuy
# Processing Record 37 of Set 4 | ekhabi
# Processing Record 38 of Set 4 | ostrovnoy
# Processing Record 39 of Set 4 | swan hill
# Processing Record 40 of Set 4 | lompoc
# Processing Record 41 of Set 4 | coahuayana
# Processing Record 42 of Set 4 | camacha
# Processing Record 43 of Set 4 | lyubim
# Processing Record 44 of Set 4 | mendahara
# City not found. Skipping...
# Processing Record 45 of Set 4 | pizhanka
# Processing Record 46 of Set 4 | port keats
# Processing Record 47 of Set 4 | oksfjord
# Processing Record 48 of Set 4 | ulkan
# Processing Record 49 of Set 4 | moss point
# Processing Record 50 of Set 4 | tura
# Processing Record 1 of Set 5 | banda aceh
# Processing Record 2 of Set 5 | port elizabeth
# Processing Record 3 of Set 5 | gushikawa
# Processing Record 4 of Set 5 | bulungu
# Processing Record 5 of Set 5 | tuktoyaktuk
# Processing Record 6 of Set 5 | chibuto
# Processing Record 7 of Set 5 | oranjemund
# Processing Record 8 of Set 5 | shingu
# Processing Record 9 of Set 5 | tazmalt
# Processing Record 10 of Set 5 | hay river
# Processing Record 11 of Set 5 | kudahuvadhoo
# Processing Record 12 of Set 5 | torbay
# Processing Record 13 of Set 5 | olafsvik
# Processing Record 14 of Set 5 | pangody
# Processing Record 15 of Set 5 | puerto escondido
# Processing Record 16 of Set 5 | yerbogachen
# Processing Record 17 of Set 5 | juneau
# Processing Record 18 of Set 5 | bambanglipuro
# Processing Record 19 of Set 5 | nanortalik
# Processing Record 20 of Set 5 | gezing
# Processing Record 21 of Set 5 | mayor pablo lagerenza
# Processing Record 22 of Set 5 | sorong
# Processing Record 23 of Set 5 | kapit
# Processing Record 24 of Set 5 | honiara
# Processing Record 25 of Set 5 | hamilton
# Processing Record 26 of Set 5 | port macquarie
# Processing Record 27 of Set 5 | zambezi
# Processing Record 28 of Set 5 | srednekolymsk
# Processing Record 29 of Set 5 | lichinga
# Processing Record 30 of Set 5 | socha
# Processing Record 31 of Set 5 | lithakia
# Processing Record 32 of Set 5 | kaitangata
# Processing Record 33 of Set 5 | sandy bay
# Processing Record 34 of Set 5 | wundanyi
# Processing Record 35 of Set 5 | elizabeth city
# Processing Record 36 of Set 5 | macaboboni
# City not found. Skipping...
# Processing Record 37 of Set 5 | mandiana
# Processing Record 38 of Set 5 | red wing
# Processing Record 39 of Set 5 | altay
# Processing Record 40 of Set 5 | rabak
# Processing Record 41 of Set 5 | los zacatones
# Processing Record 42 of Set 5 | kununurra
# Processing Record 43 of Set 5 | yumen
# Processing Record 44 of Set 5 | indramayu
# Processing Record 45 of Set 5 | pueblo
# Processing Record 46 of Set 5 | verkhnyaya inta
# Processing Record 47 of Set 5 | kempele
# Processing Record 48 of Set 5 | kismayo
# Processing Record 49 of Set 5 | mount gambier
# Processing Record 50 of Set 5 | karak
# Processing Record 1 of Set 6 | provideniya
# Processing Record 2 of Set 6 | bacolod
# Processing Record 3 of Set 6 | kodiak
# Processing Record 4 of Set 6 | rivadavia
# Processing Record 5 of Set 6 | rincon
# Processing Record 6 of Set 6 | minggang
# Processing Record 7 of Set 6 | bantry
# Processing Record 8 of Set 6 | zhob
# Processing Record 9 of Set 6 | oussouye
# Processing Record 10 of Set 6 | rabo de peixe
# Processing Record 11 of Set 6 | aklavik
# Processing Record 12 of Set 6 | meadow lake
# Processing Record 13 of Set 6 | padang
# Processing Record 14 of Set 6 | coihaique
# Processing Record 15 of Set 6 | bereda
# Processing Record 16 of Set 6 | kande
# Processing Record 17 of Set 6 | tecoanapa
# Processing Record 18 of Set 6 | codrington
# Processing Record 19 of Set 6 | atar
# Processing Record 20 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 6 | nizwa
# Processing Record 22 of Set 6 | shalya
# Processing Record 23 of Set 6 | san patricio
# Processing Record 24 of Set 6 | noumea
# Processing Record 25 of Set 6 | eucaliptus
# Processing Record 26 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 6 | lima
# Processing Record 28 of Set 6 | beringovskiy
# Processing Record 29 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 30 of Set 6 | yinchuan
# Processing Record 31 of Set 6 | fortuna
# Processing Record 32 of Set 6 | sibenik
# Processing Record 33 of Set 6 | lazarev
# Processing Record 34 of Set 6 | hualmay
# Processing Record 35 of Set 6 | porbandar
# Processing Record 36 of Set 6 | katsuura
# Processing Record 37 of Set 6 | katsiveli
# City not found. Skipping...
# Processing Record 38 of Set 6 | mehamn
# Processing Record 39 of Set 6 | dzaoudzi
# Processing Record 40 of Set 6 | sambava
# Processing Record 41 of Set 6 | shimoda
# Processing Record 42 of Set 6 | zhigansk
# Processing Record 43 of Set 6 | hofn
# Processing Record 44 of Set 6 | nemuro
# Processing Record 45 of Set 6 | two rivers
# Processing Record 46 of Set 6 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 47 of Set 6 | moerai
# Processing Record 48 of Set 6 | lagoa
# Processing Record 49 of Set 6 | bajram curri
# Processing Record 50 of Set 6 | olivenza
# Processing Record 1 of Set 7 | zhanaozen
# Processing Record 2 of Set 7 | yuzhno-kurilsk
# Processing Record 3 of Set 7 | port hardy
# Processing Record 4 of Set 7 | tautira
# Processing Record 5 of Set 7 | basco
# Processing Record 6 of Set 7 | cap-aux-meules
# Processing Record 7 of Set 7 | saint anthony
# Processing Record 8 of Set 7 | soyo
# Processing Record 9 of Set 7 | nago
# Processing Record 10 of Set 7 | uray
# Processing Record 11 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 12 of Set 7 | chapais
# Processing Record 13 of Set 7 | jacksonville
# Processing Record 14 of Set 7 | correntina
# Processing Record 15 of Set 7 | sept-iles
# Processing Record 16 of Set 7 | ipueiras
# Processing Record 17 of Set 7 | hami
# Processing Record 18 of Set 7 | touros
# Processing Record 19 of Set 7 | cabo san lucas
# Processing Record 20 of Set 7 | dingle
# Processing Record 21 of Set 7 | quime
# Processing Record 22 of Set 7 | auki
# Processing Record 23 of Set 7 | erzin
# Processing Record 24 of Set 7 | maridi
# Processing Record 25 of Set 7 | umm lajj
# Processing Record 26 of Set 7 | alugan
# Processing Record 27 of Set 7 | santa cruz
# Processing Record 28 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 7 | hohhot
# Processing Record 30 of Set 7 | brae
# Processing Record 31 of Set 7 | naze
# Processing Record 32 of Set 7 | luderitz
# Processing Record 33 of Set 7 | mokhsogollokh
# Processing Record 34 of Set 7 | terrace bay
# Processing Record 35 of Set 7 | parabel
# Processing Record 36 of Set 7 | asosa
# Processing Record 37 of Set 7 | semey
# Processing Record 38 of Set 7 | sartell
# Processing Record 39 of Set 7 | cidreira
# Processing Record 40 of Set 7 | bayir
# Processing Record 41 of Set 7 | deyang
# Processing Record 42 of Set 7 | sorland
# Processing Record 43 of Set 7 | fare
# Processing Record 44 of Set 7 | tres arroyos
# Processing Record 45 of Set 7 | yagodnoye
# Processing Record 46 of Set 7 | awbari
# Processing Record 47 of Set 7 | mpigi
# Processing Record 48 of Set 7 | san cristobal
# Processing Record 49 of Set 7 | tezpur
# Processing Record 50 of Set 7 | honningsvag
# Processing Record 1 of Set 8 | emba
# Processing Record 2 of Set 8 | okha
# Processing Record 3 of Set 8 | tandalti
# Processing Record 4 of Set 8 | rockhampton
# Processing Record 5 of Set 8 | ekangala
# Processing Record 6 of Set 8 | matara
# Processing Record 7 of Set 8 | manga
# Processing Record 8 of Set 8 | matadi
# Processing Record 9 of Set 8 | pareora
# Processing Record 10 of Set 8 | calbuco
# Processing Record 11 of Set 8 | effingham
# Processing Record 12 of Set 8 | north platte
# Processing Record 13 of Set 8 | elko
# Processing Record 14 of Set 8 | paita
# Processing Record 15 of Set 8 | lillooet
# Processing Record 16 of Set 8 | sao joao da barra
# Processing Record 17 of Set 8 | chernyshevskiy
# Processing Record 18 of Set 8 | broken hill
# Processing Record 19 of Set 8 | dharmanagar
# Processing Record 20 of Set 8 | khandyga
# Processing Record 21 of Set 8 | bengkulu
# Processing Record 22 of Set 8 | pozhva
# Processing Record 23 of Set 8 | muswellbrook
# Processing Record 24 of Set 8 | grand gaube
# Processing Record 25 of Set 8 | ust-ordynskiy
# Processing Record 26 of Set 8 | itarema
# Processing Record 27 of Set 8 | cap malheureux
# Processing Record 28 of Set 8 | sana
# Processing Record 29 of Set 8 | catio
# Processing Record 30 of Set 8 | turbat
# Processing Record 31 of Set 8 | silver city
# Processing Record 32 of Set 8 | valparaiso
# Processing Record 33 of Set 8 | pipraich
# Processing Record 34 of Set 8 | bahia de caraquez
# Processing Record 35 of Set 8 | george
# Processing Record 36 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 38 of Set 8 | korla
# Processing Record 39 of Set 8 | mount isa
# Processing Record 40 of Set 8 | yar-sale
# Processing Record 41 of Set 8 | kathmandu
# Processing Record 42 of Set 8 | sakyla
# Processing Record 43 of Set 8 | sur
# Processing Record 44 of Set 8 | piacabucu
# Processing Record 45 of Set 8 | urucui
# Processing Record 46 of Set 8 | manado
# Processing Record 47 of Set 8 | halifax
# Processing Record 48 of Set 8 | kholmogory
# Processing Record 49 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 8 | tignere
# Processing Record 1 of Set 9 | crib point
# Processing Record 2 of Set 9 | madang
# Processing Record 3 of Set 9 | goundam
# Processing Record 4 of Set 9 | bouza
# Processing Record 5 of Set 9 | campos novos
# Processing Record 6 of Set 9 | bardiyah
# Processing Record 7 of Set 9 | poum
# Processing Record 8 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 9 | dobroye
# Processing Record 10 of Set 9 | darnah
# Processing Record 11 of Set 9 | arys
# Processing Record 12 of Set 9 | nikolskoye
# Processing Record 13 of Set 9 | vestmannaeyjar
# Processing Record 14 of Set 9 | gorontalo
# Processing Record 15 of Set 9 | henties bay
# Processing Record 16 of Set 9 | wajima
# Processing Record 17 of Set 9 | chenzhou
# Processing Record 18 of Set 9 | keti bandar
# Processing Record 19 of Set 9 | kungurtug
# Processing Record 20 of Set 9 | ust-nera
# Processing Record 21 of Set 9 | sao miguel do araguaia
# Processing Record 22 of Set 9 | raudeberg
# Processing Record 23 of Set 9 | adre
# Processing Record 24 of Set 9 | panuco
# Processing Record 25 of Set 9 | malakal
# Processing Record 26 of Set 9 | kajaani
# Processing Record 27 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 9 | pirenopolis
# Processing Record 29 of Set 9 | black river
# Processing Record 30 of Set 9 | mulanje
# Processing Record 31 of Set 9 | san jose
# Processing Record 32 of Set 9 | pokhara
# Processing Record 33 of Set 9 | luanda
# Processing Record 34 of Set 9 | anadyr
# Processing Record 35 of Set 9 | labuhan
# Processing Record 36 of Set 9 | teneguiban
# City not found. Skipping...
# Processing Record 37 of Set 9 | nhulunbuy
# Processing Record 38 of Set 9 | ibotirama
# Processing Record 39 of Set 9 | vangaindrano
# Processing Record 40 of Set 9 | la ronge
# Processing Record 41 of Set 9 | mao
# Processing Record 42 of Set 9 | bayan
# Processing Record 43 of Set 9 | zhangye
# Processing Record 44 of Set 9 | hokitika
# Processing Record 45 of Set 9 | agapovka
# Processing Record 46 of Set 9 | visby
# Processing Record 47 of Set 9 | rawson
# Processing Record 48 of Set 9 | morondava
# Processing Record 49 of Set 9 | plettenberg bay
# Processing Record 50 of Set 9 | tainan
# Processing Record 1 of Set 10 | jalu
# Processing Record 2 of Set 10 | xuddur
# Processing Record 3 of Set 10 | comodoro rivadavia
# Processing Record 4 of Set 10 | roebourne
# Processing Record 5 of Set 10 | yulara
# Processing Record 6 of Set 10 | norman wells
# Processing Record 7 of Set 10 | warrington
# Processing Record 8 of Set 10 | takaka
# Processing Record 9 of Set 10 | vanimo
# Processing Record 10 of Set 10 | poltavka
# Processing Record 11 of Set 10 | bandarbeyla
# Processing Record 12 of Set 10 | egvekinot
# Processing Record 13 of Set 10 | santa maria
# Processing Record 14 of Set 10 | celestun
# Processing Record 15 of Set 10 | rio gallegos
# Processing Record 16 of Set 10 | zacualtipan
# Processing Record 17 of Set 10 | cervia
# Processing Record 18 of Set 10 | osuna
# Processing Record 19 of Set 10 | akdagmadeni
# Processing Record 20 of Set 10 | bairiki
# Processing Record 21 of Set 10 | camargo
# Processing Record 22 of Set 10 | gazanjyk
# Processing Record 23 of Set 10 | changping
# Processing Record 24 of Set 10 | dvinskoy
# Processing Record 25 of Set 10 | guerrero negro
# Processing Record 26 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 27 of Set 10 | khatanga
# Processing Record 28 of Set 10 | deming
# Processing Record 29 of Set 10 | portoferraio
# Processing Record 30 of Set 10 | viking
# Processing Record 31 of Set 10 | toktogul
# Processing Record 32 of Set 10 | wyndham
# Processing Record 33 of Set 10 | kutum
# Processing Record 34 of Set 10 | kalakamati
# Processing Record 35 of Set 10 | senno
# Processing Record 36 of Set 10 | sola
# Processing Record 37 of Set 10 | amahai
# Processing Record 38 of Set 10 | hovd
# Processing Record 39 of Set 10 | albina
# Processing Record 40 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 41 of Set 10 | mayo
# Processing Record 42 of Set 10 | panorama
# Processing Record 43 of Set 10 | angoche
# Processing Record 44 of Set 10 | mmabatho
# Processing Record 45 of Set 10 | sechura
# Processing Record 46 of Set 10 | cessnock
# Processing Record 47 of Set 10 | konstantinovka
# Processing Record 48 of Set 10 | pacific grove
# Processing Record 49 of Set 10 | wanaka
# Processing Record 50 of Set 10 | constitucion
# Processing Record 1 of Set 11 | todos santos
# Processing Record 2 of Set 11 | riyadh
# Processing Record 3 of Set 11 | bulawayo
# Processing Record 4 of Set 11 | simao
# Processing Record 5 of Set 11 | pangkalanbuun
# Processing Record 6 of Set 11 | san fernando
# Processing Record 7 of Set 11 | sivas
# Processing Record 8 of Set 11 | dalbandin
# Processing Record 9 of Set 11 | ishigaki
# Processing Record 10 of Set 11 | iquique
# Processing Record 11 of Set 11 | santa rosa
# Processing Record 12 of Set 11 | sovetskiy
# Processing Record 13 of Set 11 | bolshoye nagatkino
# Processing Record 14 of Set 11 | beloha
# Processing Record 15 of Set 11 | cayenne
# Processing Record 16 of Set 11 | jerez
# Processing Record 17 of Set 11 | half moon bay
# Processing Record 18 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 19 of Set 11 | kenai
# Processing Record 20 of Set 11 | jiayuguan
# Processing Record 21 of Set 11 | southbridge
# Processing Record 22 of Set 11 | maarianhamina
# Processing Record 23 of Set 11 | ketchikan
# Processing Record 24 of Set 11 | cherskiy
# Processing Record 25 of Set 11 | port-gentil
# Processing Record 26 of Set 11 | sao lourenco do sul
# Processing Record 27 of Set 11 | flinders
# Processing Record 28 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 11 | saldanha
# Processing Record 30 of Set 11 | los llanos de aridane
# Processing Record 31 of Set 11 | ambulu
# Processing Record 32 of Set 11 | praia
# Processing Record 33 of Set 11 | mulchen
# Processing Record 34 of Set 11 | izmir
# Processing Record 35 of Set 11 | ambunti
# Processing Record 36 of Set 11 | ponta delgada
# Processing Record 37 of Set 11 | burica
# City not found. Skipping...
# Processing Record 38 of Set 11 | manoel urbano
# Processing Record 39 of Set 11 | sabang
# Processing Record 40 of Set 11 | nishihara
# Processing Record 41 of Set 11 | dossor
# Processing Record 42 of Set 11 | clyde river
# Processing Record 43 of Set 11 | vaovai
# City not found. Skipping...
# Processing Record 44 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 45 of Set 11 | veraval
# Processing Record 46 of Set 11 | lovington
# Processing Record 47 of Set 11 | nombre de dios
# Processing Record 48 of Set 11 | limoux
# Processing Record 49 of Set 11 | kawalu
# Processing Record 50 of Set 11 | bakel
# Processing Record 1 of Set 12 | dolgoye
# Processing Record 2 of Set 12 | zwedru
# Processing Record 3 of Set 12 | hailar
# Processing Record 4 of Set 12 | eureka
# Processing Record 5 of Set 12 | chiredzi
# Processing Record 6 of Set 12 | rumonge
# Processing Record 7 of Set 12 | caranavi
# Processing Record 8 of Set 12 | richard toll
# City not found. Skipping...
# Processing Record 9 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 12 | boa vista
# Processing Record 11 of Set 12 | merauke
# Processing Record 12 of Set 12 | isiro
# Processing Record 13 of Set 12 | terekli-mekteb
# Processing Record 14 of Set 12 | thinadhoo
# Processing Record 15 of Set 12 | spassk
# Processing Record 16 of Set 12 | gimli
# Processing Record 17 of Set 12 | carauari
# Processing Record 18 of Set 12 | ballina
# Processing Record 19 of Set 12 | pisco
# Processing Record 20 of Set 12 | olga
# Processing Record 21 of Set 12 | ortigueira
# Processing Record 22 of Set 12 | yeniseysk
# Processing Record 23 of Set 12 | charters towers
# Processing Record 24 of Set 12 | kisangani
# Processing Record 25 of Set 12 | magadan
# Processing Record 26 of Set 12 | seminole
# Processing Record 27 of Set 12 | saint george
# Processing Record 28 of Set 12 | tarko-sale
# Processing Record 29 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 30 of Set 12 | omsukchan
# Processing Record 31 of Set 12 | talnakh
# Processing Record 32 of Set 12 | coueron
# Processing Record 33 of Set 12 | tabou
# Processing Record 34 of Set 12 | chau doc
# Processing Record 35 of Set 12 | kushima
# Processing Record 36 of Set 12 | alexandria
# Processing Record 37 of Set 12 | goma
# Processing Record 38 of Set 12 | nizhniy tsasuchey
# Processing Record 39 of Set 12 | high rock
# Processing Record 40 of Set 12 | neyshabur
# Processing Record 41 of Set 12 | usogorsk
# Processing Record 42 of Set 12 | dicabisagan
# Processing Record 43 of Set 12 | rute
# Processing Record 44 of Set 12 | lakes entrance
# Processing Record 45 of Set 12 | borosneu mare
# Processing Record 46 of Set 12 | kurumkan
# Processing Record 47 of Set 12 | wilmington
# Processing Record 48 of Set 12 | goure
# Processing Record 49 of Set 12 | meulaboh
# Processing Record 50 of Set 12 | barranca
# Processing Record 1 of Set 13 | mikhaylovka
# Processing Record 2 of Set 13 | atikokan
# Processing Record 3 of Set 13 | parana
# Processing Record 4 of Set 13 | urucara
# Processing Record 5 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 6 of Set 13 | penzance
# Processing Record 7 of Set 13 | mandalgovi
# Processing Record 8 of Set 13 | bujanovac
# Processing Record 9 of Set 13 | blytheville
# Processing Record 10 of Set 13 | pavlohrad
# Processing Record 11 of Set 13 | barraute
# Processing Record 12 of Set 13 | chicama
# Processing Record 13 of Set 13 | manggar
# Processing Record 14 of Set 13 | novoagansk
# Processing Record 15 of Set 13 | sangmelima
# Processing Record 16 of Set 13 | inuvik
# Processing Record 17 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 13 | kilingi-nomme
# Processing Record 20 of Set 13 | katrineholm
# Processing Record 21 of Set 13 | souillac
# Processing Record 22 of Set 13 | ciudad bolivar
# Processing Record 23 of Set 13 | mayskiy
# Processing Record 24 of Set 13 | rupert
# Processing Record 25 of Set 13 | havre-saint-pierre
# Processing Record 26 of Set 13 | komsomolskiy
# Processing Record 27 of Set 13 | bilma
# Processing Record 28 of Set 13 | mentougou
# Processing Record 29 of Set 13 | merke
# Processing Record 30 of Set 13 | port pirie
# Processing Record 31 of Set 13 | berlevag
# Processing Record 32 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 13 | husavik
# Processing Record 34 of Set 13 | andijon
# Processing Record 35 of Set 13 | mazamari
# Processing Record 36 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 13 | palana
# Processing Record 38 of Set 13 | el alto
# Processing Record 39 of Set 13 | urengoy
# Processing Record 40 of Set 13 | behbahan
# Processing Record 41 of Set 13 | xining
# Processing Record 42 of Set 13 | mae sai
# Processing Record 43 of Set 13 | vila
# Processing Record 44 of Set 13 | aromashevo
# Processing Record 45 of Set 13 | portland
# Processing Record 46 of Set 13 | yokadouma
# Processing Record 47 of Set 13 | galle
# Processing Record 48 of Set 13 | ler
# Processing Record 49 of Set 13 | xiaoshi
# Processing Record 50 of Set 13 | camana
# Processing Record 1 of Set 14 | cernesti
# Processing Record 2 of Set 14 | itoman
# Processing Record 3 of Set 14 | grenville
# Processing Record 4 of Set 14 | caravelas
# Processing Record 5 of Set 14 | zalantun
# Processing Record 6 of Set 14 | ornskoldsvik
# Processing Record 7 of Set 14 | derzhavinsk
# Processing Record 8 of Set 14 | mocorito
# Processing Record 9 of Set 14 | artesia
# Processing Record 10 of Set 14 | zemio
# Processing Record 11 of Set 14 | tawang
# Processing Record 12 of Set 14 | pimentel
# Processing Record 13 of Set 14 | salinas
# Processing Record 14 of Set 14 | sao felix do xingu
# Processing Record 15 of Set 14 | pontianak
# Processing Record 16 of Set 14 | cervo
# Processing Record 17 of Set 14 | ostersund
# Processing Record 18 of Set 14 | lashio
# Processing Record 19 of Set 14 | valdobbiadene
# Processing Record 20 of Set 14 | leningradskiy
# Processing Record 21 of Set 14 | rudnogorsk
# Processing Record 22 of Set 14 | kalmunai
# Processing Record 23 of Set 14 | salisbury
# Processing Record 24 of Set 14 | quthing
# Processing Record 25 of Set 14 | santa quiteria
# Processing Record 26 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 28 of Set 14 | durusu
# Processing Record 29 of Set 14 | mae ramat
# Processing Record 30 of Set 14 | kuala terengganu
# Processing Record 31 of Set 14 | obo
# Processing Record 32 of Set 14 | tulun
# Processing Record 33 of Set 14 | minab
# Processing Record 34 of Set 14 | high level
# Processing Record 35 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 36 of Set 14 | vidim
# Processing Record 37 of Set 14 | midland
# Processing Record 38 of Set 14 | nalut
# Processing Record 39 of Set 14 | imeni poliny osipenko
# Processing Record 40 of Set 14 | port-cartier
# Processing Record 41 of Set 14 | faya
# Processing Record 42 of Set 14 | nayoro
# Processing Record 43 of Set 14 | san borja
# Processing Record 44 of Set 14 | mogadishu
# Processing Record 45 of Set 14 | syasstroy
# Processing Record 46 of Set 14 | akureyri
# Processing Record 47 of Set 14 | maldonado
# Processing Record 48 of Set 14 | papara
# Processing Record 49 of Set 14 | terrace
# Processing Record 50 of Set 14 | vestmanna
# Processing Record 1 of Set 15 | zhaotong
# Processing Record 2 of Set 15 | russell
# Processing Record 3 of Set 15 | trairi
# Processing Record 4 of Set 15 | bataipora
# Processing Record 5 of Set 15 | luncavita
# Processing Record 6 of Set 15 | sawtell
# Processing Record 7 of Set 15 | emerald
# Processing Record 8 of Set 15 | paamiut
# Processing Record 9 of Set 15 | tricase
# Processing Record 10 of Set 15 | huambo
# Processing Record 11 of Set 15 | antsohihy
# Processing Record 12 of Set 15 | ellensburg
# Processing Record 13 of Set 15 | ilulissat
# Processing Record 14 of Set 15 | nouadhibou
# Processing Record 15 of Set 15 | sunrise manor
# Processing Record 16 of Set 15 | balkhash
# Processing Record 17 of Set 15 | lagoa vermelha
# Processing Record 18 of Set 15 | isiolo
# Processing Record 19 of Set 15 | zyryanovskiy
# City not found. Skipping...
# Processing Record 20 of Set 15 | mancora
# Processing Record 21 of Set 15 | gisborne
# Processing Record 22 of Set 15 | puerto cortes
# City not found. Skipping...
# Processing Record 23 of Set 15 | luwingu
# Processing Record 24 of Set 15 | moa
# Processing Record 25 of Set 15 | qaqortoq
# Processing Record 26 of Set 15 | kalawit
# Processing Record 27 of Set 15 | shar
# Processing Record 28 of Set 15 | lufilufi
# Processing Record 29 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 15 | kaitong
# Processing Record 31 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 15 | rio tercero
# Processing Record 33 of Set 15 | bizhbulyak
# Processing Record 34 of Set 15 | diego de almagro
# Processing Record 35 of Set 15 | mastic beach
# Processing Record 36 of Set 15 | dahod
# Processing Record 37 of Set 15 | lazaro cardenas
# Processing Record 38 of Set 15 | thohoyandou
# Processing Record 39 of Set 15 | lewiston
# Processing Record 40 of Set 15 | kirillov
# Processing Record 41 of Set 15 | talara
# Processing Record 42 of Set 15 | beidao
# Processing Record 43 of Set 15 | san policarpo
# Processing Record 44 of Set 15 | poronaysk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 692

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Atuona      PF  -9.8000 -139.0333     79.70        75           4
# 1         Vallenar      CL -28.5708  -70.7581     63.30        63           0
# 2           Castro      BR -24.7911  -50.0119     58.55        97         100
# 3         Bilibino      RU  68.0546  166.4372     14.61        71         100
# 4          Mataura      NZ -46.1927  168.8643     63.41        55          39
# ..             ...     ...      ...       ...       ...       ...         ...
# 687       Kirillov      RU  59.8630   38.3813     19.89        90         100
# 688         Talara      PE  -4.5772  -81.2719     71.98        85          97
# 689         Beidao      CN  34.5686  105.8933     54.82        59          96
# 690  San Policarpo      PH  12.1791  125.5072     81.34        76          95
# 691      Poronaysk      RU  49.2167  143.1167     36.73        90         100
#
#      Wind Speed Current Description
# 0         16.37           clear sky
# 1          2.71           clear sky
# 2          9.08     overcast clouds
# 3          1.45     overcast clouds
# 4          6.87    scattered clouds
# ..          ...                 ...
# 687        8.32     overcast clouds
# 688       16.87     overcast clouds
# 689       10.87     overcast clouds
# 690       11.88       moderate rain
# 691        5.97     overcast clouds
#
# [692 rows x 9 columns]

# %%
#Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
